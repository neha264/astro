# %%
## accuracy as function of time - with 100,000 year classifier

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from sklearn.ensemble import GradientBoostingClassifier


files = ['single ', '3', '5', '10', '20', '7306']
time = []
accuracy = []

f=plt.figure(figsize=(12,7))

for f in files:
    planets = pd.read_csv(f + 'ts.csv', skipinitialspace=True)
    
    # setting up for classification
    fates = list(set(planets['fate']))
    types = {fates[i] : i for i in range(len(fates))}
    classes = []

    for i in range(len(planets['fate'])):
        if planets['fate'][i] == "remaining":
            classes += [0]
        else:
            classes += [1]
        
    classes = np.array(classes)
    
    # training    
    features_train, features_test, classes_train, classes_test = train_test_split(planets, classes, test_size=0.3, random_state=7)

    ids_train = features_train['planet'].to_numpy()
    features_train.drop(['run', 'planet', 'fate', 'end time'], axis=1, inplace=True)

    cols = features_train.columns
    features_train = features_train.to_numpy()

    ids_test = features_test['planet'].to_numpy()
    features_test.drop(['run', 'planet', 'fate', 'end time'], axis=1, inplace=True)
    features_test = features_test.to_numpy()
    
    # testing
    classifier = GradientBoostingClassifier(random_state=7)
    classifier.fit(features_train, classes_train)
    
    classes_predict = classifier.predict(features_test)
    a = accuracy_score(classes_test, classes_predict) * 100

    # ready for graphing
    accuracy.append(a)
    if f == 'single ':
        t = 1
    else:
        t = int(f)
    time.append(np.log10(t*13.69))
    

plt.plot(time, accuracy, marker = 'o')
    
plt.ylabel('Accuracy')
plt.xlabel('Log10(Time)')
plt.title("Accuracy as a function of time")
# Out:
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'Accuracy as a function of time')

# %%
## accuracy as function of time - with 100,000 year classifier

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from sklearn.ensemble import GradientBoostingClassifier


files = ['single ', '3', '5', '10', '20']
time = []
accuracy = []

f=plt.figure(figsize=(12,7))

for f in files:
    planets = pd.read_csv(f + 'ts.csv', skipinitialspace=True)
    
    # setting up for classification
    fates = list(set(planets['fate']))
    types = {fates[i] : i for i in range(len(fates))}
    classes = []

    for i in range(len(planets['fate'])):
        if planets['fate'][i] == "remaining":
            classes += [0]
        else:
            classes += [1]
        
    classes = np.array(classes)
    
    # training    
    features_train, features_test, classes_train, classes_test = train_test_split(planets, classes, test_size=0.3, random_state=7)

    ids_train = features_train['planet'].to_numpy()
    features_train.drop(['run', 'planet', 'fate', 'end time'], axis=1, inplace=True)

    cols = features_train.columns
    features_train = features_train.to_numpy()

    ids_test = features_test['planet'].to_numpy()
    features_test.drop(['run', 'planet', 'fate', 'end time'], axis=1, inplace=True)
    features_test = features_test.to_numpy()
    
    # testing
    classifier = GradientBoostingClassifier(random_state=7)
    classifier.fit(features_train, classes_train)
    
    classes_predict = classifier.predict(features_test)
    a = accuracy_score(classes_test, classes_predict) * 100

    # ready for graphing
    accuracy.append(a)
    if f == 'single ':
        t = 1
    else:
        t = int(f)
#     time.append(np.log10(t*13.69))
    time.append(t*13.69)
    

plt.plot(time, accuracy, marker = 'o')
    
plt.ylabel('Accuracy')
plt.xlabel('Time')
plt.title("Accuracy as a function of time")
# Out:
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'Accuracy as a function of time')

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import pylab


data = dict()

cols = ['Time','mass','a','e','i','omega','Omega','M','dist_jac','dist_cen','x','y','z','u','v','w']


for rn in range(1,5):
    data[rn] = dict()
    for planetnum in range(1,11):
        data[rn][planetnum] = dict()
        pl = pd.read_csv(r'/Users/neha/Documents/lanl/classifier/run'+str(rn)+'/PL'+str(planetnum)+'.el', skiprows=2, delimiter=r"\s+", names=cols) 
        for col in cols:
            data[rn][planetnum][col] = dict()
            try:
                data[rn][planetnum][col] = pl[col]
            except:
                pass

# %%
# plotting semi-major vs time


for run in range(1,5):
    f=plt.figure(figsize=(12,7))
    for planet in range(1,11):
        plt.plot((data[run][planet]['Time']), np.log(data[run][planet]['a']))

    plt.ylabel('Log10(Semi-major axis)')
    plt.xlabel('Time (years)')
    plt.xlim(0, 1300)
    plt.title("Run " + str(run))
# Out:
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# plotting semi major axis vs jacobi dist

for run in range(1,5):
    f=plt.figure(figsize=(12,7))
    for planet in range(1,11):
        plt.plot((data[run][planet]['Time']), np.log(data[run][planet]['dist_jac']), linewidth = 1.2)

    plt.ylabel('Log10(Jacobi Distance)')
    plt.xlabel('Time (years)')
    plt.xlim(0, 1300)
    # plt.ylim(-0.5, 2.5)
    plt.title("Run " + str(run))
