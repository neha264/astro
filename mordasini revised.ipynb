# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import pylab

# data = dict()
planets = []
cols = ['Time','mass','a','e','i','omega','Omega','M','dist_jac','dist_cen','x','y','z','u','v','w']
    
for sample in range(1,11):
    planets.append(pd.read_csv(r'/Users/neha/Documents/lanl/mordasini/PL'+str(sample)+'.el', skiprows=2, delimiter=r"\s+", names=cols)) 
#     planet = pd.read_csv(r'/Users/neha/Documents/lanl/mordasini/PL'+str(sample)+'.el', skiprows=2, delimiter=r"\s+", names=cols) 
#     data[sample] = dict()
#     data[sample]['Time'] = planet['Time']
#     data[sample]['mass'] = planet['mass']
#     data[sample]['a'] = planet['a']
#     data[sample]['e'] = planet['e']
#     data[sample]['i'] = planet['i']
#     data[sample]['omega'] = planet['omega']
#     data[sample]['Omega'] = planet['Omega']
#     data[sample]['M']=planet['M']
#     data[sample]['dist_jac']=planet['dist_jac']
#     data[sample]['dist_cen']=planet['dist_cen']
#     data[sample]['x']=planet['x']
#     data[sample]['y']=planet['y']
#     data[sample]['z']=planet['z']
#     data[sample]['u']=planet['u']
#     data[sample]['v']=planet['v']
#     data[sample]['w']=planet['w']

# %%
# plotting semi-major vs time (overlayed plots)

f=plt.figure(figsize=(12,7))

for planet in planets:
    plt.plot(planet['Time'], np.log10(planet['a']))


plt.ylabel('Log10(Semi-major axis)')
plt.xlabel('Time (years)')
plt.xlim((0, 250000))
# Out:
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.0, 250000.0)

# %%
# plotting semi-major vs time (overlayed plots)

import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.pyplot

f=plt.figure(figsize=(12,7))
jet = cm = plt.get_cmap('jet')
values = range(len(planets))
cNorm  = colors.Normalize(vmin=0, vmax=values[-1])
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

for i in range(len(planets)):
    colorVal = scalarMap.to_rgba(values[i])
    plt.plot(planets[i]['Time'], np.log10(planets[i]['a']),color=colorVal, label=colorText)

plt.ylabel('Log10(Semi-major axis)')
plt.xlabel('Time (years)')
plt.xlim((0, 250000))
plt.legend()
plt.show()
# Out:
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/neha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ...

# %%
# plotting jacobi distance vs time (overlayed plots), log 10

f=plt.figure(figsize=(12,7))

for planet in planets:
    plt.plot(planet['Time'], np.log10(planet['dist_jac']), linewidth = 0.05)


plt.ylabel('Log10(Jacobi Distance)')
plt.xlabel('Time (years)')
plt.xlim((0, 250000))
# Out:
# (0.0, 250000.0)

# %%
# plotting jacobi distance vs time (overlayed plots)

f=plt.figure(figsize=(12,7))

for planet in planets:
    plt.plot(planet['Time'], planet['dist_jac'], linewidth = 0.1)


plt.ylabel('Jacobi Distance')
plt.xlabel('Time (years)')
plt.xlim((0, 250000))
# Out:
# (0.0, 250000.0)

# %%
for planet in planets:
    print(np.max(planet['Time']))
# Out:
# 135523.613963
# 10000000.0
# 1172621.49213
# 10000000.0
# 119411.362081
# 10000000.0
# 405284.052019
# 41026.6940452
# 561642.7104720001
# 217878.16564000002
